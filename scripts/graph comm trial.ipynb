# %% [markdown]
# # trial code for graph comm

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
from scipy.sparse import csgraph
# Load the TNBC dataset
adata = sc.read_h5ad("C:/Users/zzrtroy/OneDrive/umich/2025 Fall/BIOINF593/final_project/data/bc_dataset.h5ad")
# Check the structure of the AnnData object
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 42512 × 28200
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'subtype', 'celltype_subset', 'celltype_minor', 'celltype_major', 'ident', 'label', 'n_counts', 'cell_type', 'size_factors'
#     var: 'n_cells', 'feature_name', 'hvg', 'hvg_score'
#     uns: '_from_cache', 'ccc_target', 'data_reference', 'data_url', 'dataset_description', 'dataset_id', 'dataset_name', 'dataset_organism', 'dataset_reference', 'dataset_summary', 'dataset_url', 'knn', 'normalization_id', 'pca_variance', 'target_organism', 'var_names_all'
#     obsm: 'X_pca'
#     varm: 'pca_loadings'
#     layers: 'counts', 'normalized'
#     obsp: 'knn_connectivities', 'knn_distances'

# %%
# Ensure we are working with the main expression matrix
# Normalization and log transformation steps
if 'normalized' in adata.layers:
    # If a normalized layer exists, use it
    adata.X = adata.layers['normalized']
else:
    # Normalize total counts
    sc.pp.normalize_total(adata, target_sum=1e4, inplace=True)  # Normalize the main data matrix
    sc.pp.log1p(adata)  # Log transformation

# Extract the expression matrix for further analysis
X = adata.X

# Calculate the pairwise distances
distance_matrix = pairwise_distances(X)

# Construct the graph using a distance threshold for connectivity
threshold = 0.5  # Set this threshold according to your analysis needs
adjacency_matrix = (distance_matrix < threshold).astype(int)

# Create the graph from the adjacency matrix
G = nx.from_numpy_array(adjacency_matrix)

# Optionally, compute graph metrics (e.g., number of edges, nodes)
num_edges = G.number_of_edges()
num_nodes = G.number_of_nodes()
print(f'Number of nodes: {num_nodes}, Number of edges: {num_edges}')

# Perform community detection using the Girvan-Newman algorithm
def girvan_newman(G):
    while G.number_of_edges() > 0:
        # Find the edge with the highest betweenness centrality
        edge_betweenness = nx.edge_betweenness_centrality(G)
        edge_to_remove = max(edge_betweenness, key=edge_betweenness.get)
        G.remove_edge(*edge_to_remove)

        # Check connected components to find communities
        components = list(nx.connected_components(G))
        if len(components) > 1:
            return components

# Apply the Girvan-Newman algorithm
communities = girvan_newman(G)

# Map nodes to communities
community_map = {node: idx for idx, community in enumerate(communities) for node in community}

# Assign community information back to the AnnData object
adata.obs['community'] = [community_map[i] for i in range(num_nodes)]

# Visualization of the communities
plt.figure(figsize=(10, 8))
nx.draw(G, node_color=list(community_map.values()), with_labels=False, node_size=50)
plt.title('Cell Communication Network')
plt.show()

# Further analysis: Average expression per community
average_expression = {}
for community_id in set(community_map.values()):
    member_indices = [i for i, cid in community_map.items() if cid == community_id]
    average_expression[community_id] = np.mean(X[member_indices], axis=0)

# Prepare a DataFrame of average expression
average_expression_df = pd.DataFrame(average_expression)

# Plot average expression
average_expression_df.plot(kind='bar', figsize=(12, 6))
plt.title('Average Expression per Community')
plt.xlabel('Genes/Cytokines')
plt.ylabel('Average Expression')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 15
#      12 X = adata.X
#      14 # Calculate the pairwise distances
# ---> 15 distance_matrix = pairwise_distances(X)
#      17 # Construct the graph using a distance threshold for connectivity
#      18 threshold = 0.5  # Set this threshold according to your analysis needs
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:2476, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, ensure_all_finite, **kwds)
#    2473         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2474     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2476 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:1960, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1957 X, Y, dtype = _return_float_dtype(X, Y)
#    1959 if effective_n_jobs(n_jobs) == 1:
# -> 1960     return func(X, Y, **kwds)
#    1962 # enforce a threading backend to prevent data communication overhead
#    1963 fd = delayed(_dist_wrapper)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:388, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     382     if Y_norm_squared.shape != (1, Y.shape[0]):
#     383         raise ValueError(
#     384             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     385             f"Y_norm_squared of shape {original_shape}."
#     386         )
# --> 388 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:421, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     416         YY = None
#     418 if X.dtype == xp.float32 or Y.dtype == xp.float32:
#     419     # To minimize precision issues with float32, we compute the distance
#     420     # matrix on chunks of X and Y upcast to float64
# --> 421     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     422 else:
#     423     # if dtype is already float64, no need to chunk and upcast
#     424     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\pairwise.py:647, in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     644 else:
#     645     YY_chunk = YY[:, y_slice]
# --> 647 d = -2 * safe_sparse_dot(X_chunk, Y_chunk.T, dense_output=True)
#     648 d += XX_chunk
#     649 d += YY_chunk
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\extmath.py:203, in safe_sparse_dot(a, b, dense_output)
#     201         ret = xp.tensordot(a, b, axes=[-1, b_axis])
#     202 else:
# --> 203     ret = a @ b
#     205 if (
#     206     sparse.issparse(a)
#     207     and sparse.issparse(b)
#     208     and dense_output
#     209     and hasattr(ret, "toarray")
#     210 ):
#     211     return ret.toarray()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\scipy\sparse\_base.py:731, in _spbase.__matmul__(self, other)
#     728 if isscalarlike(other):
#     729     raise ValueError("Scalar operands are not allowed, "
#     730                      "use '*' instead")
# --> 731 return self._matmul_dispatch(other)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\scipy\sparse\_base.py:636, in _spbase._matmul_dispatch(self, other)
#     632     if N != other.shape[0]:
#     633         raise ValueError(
#     634             f"{err_prefix} (n,k={N}),(k={other.shape[0]},m)->(n,m)"
#     635         )
# --> 636     return self._matmul_sparse(other)
#     638 # If it's a list or whatever, treat it like an array
#     639 other_a = np.asanyarray(other)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\scipy\sparse\_compressed.py:570, in _cs_matrix._matmul_sparse(self, other)
#     566 idx_dtype = self._get_index_dtype((self.indptr, self.indices,
#     567                              other.indptr, other.indices))
#     569 fn = getattr(_sparsetools, self.format + '_matmat_maxnnz')
# --> 570 nnz = fn(M, N,
#     571          np.asarray(self.indptr, dtype=idx_dtype),
#     572          np.asarray(self.indices, dtype=idx_dtype),
#     573          np.asarray(other.indptr, dtype=idx_dtype),
#     574          np.asarray(other.indices, dtype=idx_dtype))
#     575 if nnz == 0:
#     576     if new_shape == ():
#
# KeyboardInterrupt:

# %%
nx.from_numpy_array
